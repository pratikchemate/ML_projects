# %%
from sklearn.datasets import fetch_california_housing 
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd;
import seaborn as sns
# %matplotlib inline

# %%
df = fetch_california_housing()

# %%
type(df)
# Out:
# sklearn.utils._bunch.Bunch

# %%
df
# Out:
# {'data': array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#            37.88      , -122.23      ],
#         [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#            37.86      , -122.22      ],
#         [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#            37.85      , -122.24      ],
#         ...,
#         [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#            39.43      , -121.22      ],
#         [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#            39.43      , -121.32      ],
#         [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
#            39.37      , -121.24      ]], shape=(20640, 8)),
#  'target': array([4.526, 3.585, 3.521, ..., 0.923, 0.847, 0.894], shape=(20640,)),
#  'frame': None,
#  'target_names': ['MedHouseVal'],
#  'feature_names': ['MedInc',
#   'HouseAge',
#   'AveRooms',
#   'AveBedrms',
#   'Population',
# ...

# %%
pd.DataFrame(df.data)
# Out:
#             0     1         2         3       4         5      6       7
# 0      8.3252  41.0  6.984127  1.023810   322.0  2.555556  37.88 -122.23
# 1      8.3014  21.0  6.238137  0.971880  2401.0  2.109842  37.86 -122.22
# 2      7.2574  52.0  8.288136  1.073446   496.0  2.802260  37.85 -122.24
# 3      5.6431  52.0  5.817352  1.073059   558.0  2.547945  37.85 -122.25
# 4      3.8462  52.0  6.281853  1.081081   565.0  2.181467  37.85 -122.25
# ...       ...   ...       ...       ...     ...       ...    ...     ...
# 20635  1.5603  25.0  5.045455  1.133333   845.0  2.560606  39.48 -121.09
# 20636  2.5568  18.0  6.114035  1.315789   356.0  3.122807  39.49 -121.21
# 20637  1.7000  17.0  5.205543  1.120092  1007.0  2.325635  39.43 -121.22
# 20638  1.8672  18.0  5.329513  1.171920   741.0  2.123209  39.43 -121.32
# 20639  2.3886  16.0  5.254717  1.162264  1387.0  2.616981  39.37 -121.24
#
# [20640 rows x 8 columns]

# %%
dataset = pd.DataFrame(df.data)
dataset.columns=df.feature_names
dataset.head()
# Out:
#    MedInc  HouseAge  AveRooms  ...  AveOccup  Latitude  Longitude
# 0  8.3252      41.0  6.984127  ...  2.555556     37.88    -122.23
# 1  8.3014      21.0  6.238137  ...  2.109842     37.86    -122.22
# 2  7.2574      52.0  8.288136  ...  2.802260     37.85    -122.24
# 3  5.6431      52.0  5.817352  ...  2.547945     37.85    -122.25
# 4  3.8462      52.0  6.281853  ...  2.181467     37.85    -122.25
#
# [5 rows x 8 columns]

# %%
dataset['Price'] = df.target

# %%
dataset
# Out:
#        MedInc  HouseAge  AveRooms  ...  Latitude  Longitude  Price
# 0      8.3252      41.0  6.984127  ...     37.88    -122.23  4.526
# 1      8.3014      21.0  6.238137  ...     37.86    -122.22  3.585
# 2      7.2574      52.0  8.288136  ...     37.85    -122.24  3.521
# 3      5.6431      52.0  5.817352  ...     37.85    -122.25  3.413
# 4      3.8462      52.0  6.281853  ...     37.85    -122.25  3.422
# ...       ...       ...       ...  ...       ...        ...    ...
# 20635  1.5603      25.0  5.045455  ...     39.48    -121.09  0.781
# 20636  2.5568      18.0  6.114035  ...     39.49    -121.21  0.771
# 20637  1.7000      17.0  5.205543  ...     39.43    -121.22  0.923
# 20638  1.8672      18.0  5.329513  ...     39.43    -121.32  0.847
# 20639  2.3886      16.0  5.254717  ...     39.37    -121.24  0.894
#
# [20640 rows x 9 columns]

# %%
x = dataset.iloc[:,:-1]
y = dataset.iloc[:,-1]

# %%
x.head()
# Out:
#    MedInc  HouseAge  AveRooms  ...  AveOccup  Latitude  Longitude
# 0  8.3252      41.0  6.984127  ...  2.555556     37.88    -122.23
# 1  8.3014      21.0  6.238137  ...  2.109842     37.86    -122.22
# 2  7.2574      52.0  8.288136  ...  2.802260     37.85    -122.24
# 3  5.6431      52.0  5.817352  ...  2.547945     37.85    -122.25
# 4  3.8462      52.0  6.281853  ...  2.181467     37.85    -122.25
#
# [5 rows x 8 columns]

# %%
y.head()
# Out:
# 0    4.526
# 1    3.585
# 2    3.521
# 3    3.413
# 4    3.422
# Name: Price, dtype: float64

# %%
lin_reg = LinearRegression()
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.33,random_state=42)
mse = cross_val_score(lin_reg,x_train,y_train,scoring='neg_mean_squared_error',cv=5)

# %%
mse
# Out:
# array([-0.54099828, -0.49871687, -0.50480739, -0.5200183 , -0.55070903])

# %%
print(mse)
# Out:
# [-0.54099828 -0.49871687 -0.50480739 -0.5200183  -0.55070903]

# %%
mean_mse = np.mean(mse)

# %%
mean_mse
# Out:
# np.float64(-0.5230499763383932)

# %%
lin_reg.fit(x,y)
# Out:
# LinearRegression()

# %%
## Ridge

# %%
from sklearn.linear_model import Ridge,Lasso
from sklearn.model_selection import GridSearchCV

# %%
ridge = Ridge()
params = {'alpha':[1e-15,1e-10,1e-8,1e-5,1e-3,1e-2,1,5,8,10,15,20,25,30,40,50,55,60,100]}

# %%
r_regressor = GridSearchCV(ridge, params, scoring='neg_mean_squared_error',cv=10)

# %%
r_regressor.fit(x,y)
# Out:
# GridSearchCV(cv=10, estimator=Ridge(),
#              param_grid={'alpha': [1e-15, 1e-10, 1e-08, 1e-05, 0.001, 0.01, 1,
#                                    5, 8, 10, 15, 20, 25, 30, 40, 50, 55, 60,
#                                    100]},
#              scoring='neg_mean_squared_error')

# %%
print(r_regressor)
# Out:
# GridSearchCV(cv=10, estimator=Ridge(),
#              param_grid={'alpha': [1e-15, 1e-10, 1e-08, 1e-05, 0.001, 0.01, 1,
#                                    5, 8, 10, 15, 20, 25, 30, 40, 50, 55, 60,
#                                    100]},
#              scoring='neg_mean_squared_error')

# %%
print(r_regressor.best_params_)
print(r_regressor.best_score_)
# Out:
# {'alpha': 100}
# -0.5505461807589811

# %%
lasso = Lasso()

# %%
# Out:
# c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.423e+03, tolerance: 2.545e+00
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.449e+03, tolerance: 2.438e+00
#   model = cd_fast.enet_coordinate_descent(
# ...

# %%
print(l_regressor.best_params_)
print(l_regressor.best_score_)
# Out:
# {'alpha': 0.001}
# -0.5582759293868984

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.33,random_state=42)

# %%
l_regressor = GridSearchCV(lasso, params, scoring='neg_mean_squared_error',cv=10)
l_regressor.fit(x_train,y_train)
# Out:
# c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.589e+03, tolerance: 1.655e+00
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.319e+03, tolerance: 1.656e+00
#   model = cd_fast.enet_coordinate_descent(
# ...

# %%
print(l_regressor.best_params_)
print(l_regressor.best_score_)
# Out:
# {'alpha': 1e-05}
# -0.5221885158145831
